# %%
from __future__ import division
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = (8.0, 8.0)
import CameraNetwork
import CameraNetwork.global_settings as gs
import datetime
import cv2
import Image
import ImageDraw
import os
import pandas as pd
import time
from tqdm import tqdm_notebook
import traceback
# Out:
# c:\users\user\documents\code\cameranetwork_git\CameraNetwork\transformation_matrices.py:1934: UserWarning: failed to import module _transformations
#   warnings.warn("failed to import module %s" % name)

# %%
c = CameraNetwork.CLIclient()
proxy_params = CameraNetwork.retrieve_proxy_parameters()
c.start(proxy_params)
time.sleep(3)
SERVERS = c.client_instance.servers
print SERVERS
# Out:
# ['109', '109L', '110', '110L', '111', '111L', '112', '113L', '114', '114L', '115L', '116', '116L', '117L', '118', '118L', '119', '119L', '120']

# %%
img = c.seek("112", datetime.datetime(2017, 5, 4, 11, 45), "3", 95, 501)[0][0]

# %%
dimg = img.astype(np.float)**0.6
dimg = (dimg/dimg.max()*200).astype(np.uint8)
cv2.imwrite("EE roof2.jpg", dimg[::-1, :, ::-1])
# Out:
# True

# %%
plt.imshow(img)

# %%
img = c.seek("114L", datetime.datetime(2017, 3, 4, 10, 15), "3", 95, 801)[0][0]

# %%
dimg = img.astype(np.float)**0.6
dimg = (dimg/dimg.max()*200).astype(np.uint8)
dimg = dimg.transpose((1, 0, 2))[:, ::-1, :]
cv2.imwrite("EE roof3.jpg", dimg[..., ::-1])
# Out:
# True

# %%
plt.imshow(dimg)
