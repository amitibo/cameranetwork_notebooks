# %%
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.models import Label
from bokeh.plotting import figure
import cPickle
import numpy as np
import os

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="85612615-8c78-4df6-ac0e-bc6ccfffbc87">Loading BokehJS ...</span>
#     </div>

# %%
BASE_PATH = r'../../scripts_client/reconstruction/2016_10_23_11_10_00/'

# %%
with open(os.path.join(BASE_PATH, 'Xs.pkl'), 'rb') as f:
    Xs = cPickle.load(f)
with open(os.path.join(BASE_PATH, 'Ys.pkl'), 'rb') as f:
    Ys = cPickle.load(f)
with open(os.path.join(BASE_PATH, 'Zs.pkl'), 'rb') as f:
    Zs = cPickle.load(f)
with open(os.path.join(BASE_PATH, 'PHIs.pkl'), 'rb') as f:
    PHIs = cPickle.load(f)
with open(os.path.join(BASE_PATH, 'PSIs.pkl'), 'rb') as f:
    PSIs = cPickle.load(f)

# %%
def quiver(Xs, Ys, Zs, PSIs, PHIs, length = 6000, skip=5):
    p1 = figure(x_range=(-3000, 3000), y_range=(-3000, 3000))
    p2 = figure(x_range=(-3000, 3000), y_range=(-500, 5500))
    cam_ids = Xs.keys()
    for cam_id in cam_ids:
        X, Y, Z, PSI, PHI = \
            Xs[cam_id], Ys[cam_id], Zs[cam_id], PSIs[cam_id], PHIs[cam_id]

        x0 = X[::skip, ::skip].flatten()
        y0 = Y[::skip, ::skip].flatten()
        z0 = Z[::skip, ::skip].flatten()
        psi = PSI[::skip, ::skip].flatten()
        phi = PHI[::skip, ::skip].flatten()

        x1 = x0 + length * np.sin(phi)
        y1 = y0 + length * np.cos(phi)
        z1 = z0 + length * np.cos(psi)
        
        p1.segment(x0, y0, x1, y1)
        p2.segment(x0, z0, x1, z1)
        
        mytext = Label(x=x0[0], y=y0[0], text=cam_id)
        p1.add_layout(mytext)

        mytext = Label(x=x0[0], y=z0[0], text=cam_id)
        p2.add_layout(mytext)

    show(row(p1, p2))

# %%
quiver(Xs, Ys, Zs, PSIs, PHIs)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="9ee69e92-cecb-49c5-a064-93489d4a2156"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#9ee69e92-cecb-49c5-a064-93489d4a2156").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9ee69e92-cecb-49c5-a064-93489d4a2156");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9ee69e92-cecb-49c5-a064-93489d4a2156' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e18e9a5f-08a2-4c97-a9d2-2d52141aa7a2":{"roots":{"references":[{"attributes":{"below":[{"id":"0bec82f1-010e-41eb-9136-72540582fa2c","type":"LinearAxis"}],"left":[{"id":"d320fa41-a035-4a5a-916b-aa9e8eff618b","type":"LinearAxis"}],"renderers":[{"id":"0bec82f1-010e-41eb-9136-72540582fa2c","type":"LinearAxis"},{"id":"8ebbabc2-a9dc-49fe-8f47-5f901c2ec9b8","type":"Grid"},{"id":"d320fa41-a035-4a5a-916b-aa9e8eff618b","type":"LinearAxis"},{"id":"417e1646-d9d8-44d9-bda0-7c017080b028","type":"Grid"},{"id":"c050e9ef-955a-403a-90eb-135a3de6c388","type":"BoxAnnotation"},{"id":"c98125da-a185-4a5b-b1a3-4a7503bcdb22","type":"GlyphRenderer"},{"id":"64c8cf64-9c3e-4e15-81b5-25631efcfb75","type":"Label"},{"id":"b085bea6-a145-476d-81eb-aa9b01be6325","type":"GlyphRenderer"},{"id":"7c73aea6-7dfc-476a-9b8d-fde16b56455d","type":"Label"},{"id":"cd5349ad-ae3e-47de-8b59-beec90a24dd1","type":"GlyphRenderer"},{"id":"8017719d-b9e6-4adb-968f-824d4429eb5d","type":"Label"},{"id":"4a6aec68-0170-4105-95d1-50a6e81f09b2","type":"GlyphRenderer"},{"id":"0cb45e16-8a5c-4fa8-b0f2-68645090d32a","type":"Label"},{"id":"1b7b2cdd-b57b-4ee8-9f32-99698e3a1960","type":"GlyphRenderer"},{"id":"5dc5061f-b395-41a9-938b-dc00e7c0637a","type":"Label"},{"id":"d96b93f9-530f-45b6-b8c3-0c9f9bfb9715","type":"GlyphRenderer"},{"id":"7e28eb66-9247-45d3-8d53-5f35368d01ac","type":"Label"},{"id":"e75eb863-de05-448a-b522-38232e5fe2a1","type":"GlyphRenderer"},{"id":"03171d77-8d40-4bf1-9f32-744c6e950f60","type":"Label"}],"title":{"id":"350f39a4-9209-427c-86fa-0ef1eb706fd5","type":"Title"},"tool_events":{"id":"52cf0ff3-f1bc-41df-8d07-4b173e3cea8d","type":"ToolEvents"},"toolbar":{"id":"cd17b2fb-8394-4f87-893c-fb442c911801","type":"Toolbar"},"x_range":{"id":"74df0c5f-a2d8-4cb4-b57d-f80a80741765","type":"Range1d"},"y_range":{"id":"ea2d23f2-1099-46cd-b74a-3b66f0afa69f","type":"Range1d"}},"id":"6dc4e485-2dcd-4577-b775-9e68ad7c48c4","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"af216648-ce22-4f77-8f25-356f13f3b9f9","subtype":"Figure","type":"Plot"}},"id":"02d44c88-5b7e-428e-b818-3397a9afc072","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"6dc4e485-2dcd-4577-b775-9e68ad7c48c4","subtype":"Figure","type":"Plot"},"ticker":{"id":"01907b7b-49af-48d1-8a0c-0b39f3ed09f5","type":"BasicTicker"}},"id":"417e1646-d9d8-44d9-bda0-7c017080b028","type":"Grid"},{"attributes":{},"id":"e7a9f535-9618-4f3e-947e-1cfad447332b","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"af216648-ce22-4f77-8f25-356f13f3b9f9","subtype":"Figure","type":"Plot"},"ticker":{"id":"5eeac325-2ebd-455e-9858-b19f6bdf9977","type":"BasicTicker"}},"id":"06fc2082-62b5-4d80-aa7a-027d944d0d25","type":"Grid"},{"attributes":{"line_color":{"value":"#1f77b4"},"x0":{"field":"x0"},"x1":{"field":"x1"},"y0":{"field":"y0"},"y1":{"field":"y1"}},"id":"8c5da963-183c-47a6-8dd6-d938fee4ea13","type":"Segment"},{"attributes":{"formatter":{"id":"5ecf26d4-35d2-437c-b097-790184d249d8","type":"BasicTickFormatter"},"plot":{"id":"af216648-ce22-4f77-8f25-356f13f3b9f9","subtype":"Figure","type":"Plot"},"ticker":{"id":"603abc33-7417-44ad-9246-f58f16d39a70","type":"BasicTicker"}},"id":"1a837f73-fda2-43f5-913b-f3230e48ee4c","type":"LinearAxis"},{"attributes":{"data_source":{"id":"3c6b97ae-6a42-4c1b-af6d-1dbddbed7ba8","type":"ColumnDataSource"},"glyph":{"id":"7773e570-7a86-4b69-bd9f-b7f0ce39bc86","type":"Segment"},"hover_glyph":null,"nonselection_glyph":{"id":"2ca77c46-4a36-4d7f-a6e8-9e8577e4f141","type":"Segment"},"selection_glyph":null},"id":"1b7b2cdd-b57b-4ee8-9f32-99698e3a1960","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#1f77b4"},"x0":{"field":"x0"},"x1":{"field":"x1"},"y0":{"field":"y0"},"y1":{"field":"y1"}},"id":"af9b7a9d-abd7-45ab-a116-70a51e7394f2","type":"Segment"},{"attributes":{"plot":{"id":"af216648-ce22-4f77-8f25-356f13f3b9f9","subtype":"Figure","type":"Plot"},"text":"107","x":-205221.3279750633,"y":251622.61450811167},"id":"d91ee9bf-9157-445c-a630-08d7586e5c9b","type":"La ...

# %%
from mayavi import mlab
mlab.init_notebook(width=320, height=320)
# Out:
# Notebook initialized with x3d backend.

# %% [markdown]
# #s = mlab.test_plot3d()
# #s
