# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
lidar_df = pd.read_csv(r"../../data/lidar/2017_04_22/-20170422_0800-0900-21smooth.txt", delimiter="\t", index_col=0)
lidar_df.head()
# Out:
#              Beta355 (Mm^-1 sr^-1):  error beta355 (Mm^-1 sr^-1)  \
# Height(km):
# 0.115822                  -7.310998                          0.0
# 0.123293                  -7.270647                          0.0
# 0.130765                  -7.225339                          0.0
# 0.138236                  -7.173630                          0.0
# 0.145708                  -7.112251                          0.0
#
#              Beta532 (Mm^-1 sr^-1):  error beta532 (Mm^-1 sr^-1)  \
# Height(km):
# 0.115822                  -1.358923                          0.0
# 0.123293                  -1.348471                          0.0
# 0.130765                  -1.336122                          0.0
# 0.138236                  -1.322223                          0.0
# 0.145708                  -1.306397                          0.0
#
#              Beta1064 (Mm^-1 sr^-1):  error beta1064 (Mm^-1 sr^-1)  \
# Height(km):
# 0.115822                   -0.048960                           0.0
# 0.123293                   -0.040382                           0.0
# 0.130765                   -0.030342                           0.0
# 0.138236                   -0.018973                           0.0
# 0.145708                   -0.006243                           0.0
#
#              alpha355 (Mm^-1 sr^-1):  error alpha355 (Mm^-1)  \
# Height(km):
# 0.115822                 -365.549880                     0.0
# 0.123293                 -363.532363                     0.0
# 0.130765                 -361.266934                     0.0
# 0.138236                 -358.681513                     0.0
# 0.145708                 -355.612539                     0.0
#
#              alpha532 (Mm^-1 sr^-1):  error alpha532 (Mm^-1)  \
# Height(km):
# 0.115822                  -67.946129                     0.0
# 0.123293                  -67.423567                     0.0
# 0.130765                  -66.806125                     0.0
# 0.138236                  -66.111158                     0.0
# 0.145708                  -65.319866                     0.0
#
#                        ...              Height NF 355 (km):  \
# Height(km):            ...
# 0.115822               ...                         0.115822
# 0.123293               ...                         0.123293
# 0.130765               ...                         0.130765
# 0.138236               ...                         0.138236
# 0.145708               ...                         0.145708
#
#              Beta355 NF (Mm^-1 sr^-1):  error beta355 NF (Mm^-1 sr^-1)  \
# Height(km):
# 0.115822                     -2.934704                             NaN
# 0.123293                     -2.509770                             NaN
# 0.130765                     -2.081802                             NaN
# 0.138236                     -1.646046                             NaN
# 0.145708                     -1.181717                             NaN
#
#              alpha 355 NF (Mm^-1 sr^-1):  error alpha355 NF (Mm^-1)  \
# Height(km):
# 0.115822                     -146.735210                        0.0
# 0.123293                     -125.488507                        0.0
# 0.130765                     -104.090075                        0.0
# 0.138236                      -82.302302                        0.0
# 0.145708                      -59.085850                        0.0
#
#              Spar 355 NF (sr):  error Spar 355 NF (sr)  \
# Height(km):
# 0.115822                  50.0                     0.0
# 0.123293                  50.0                     0.0
# 0.130765                  50.0                     0.0
# 0.138236                  50.0                     0.0
# 0.145708                  50.0                     0.0
#
#              BetaMOL 355 (m^-1 sr^-1)  BetaMOL 532 (m^-1 sr^-1)  \
# Height(km):
# 0.115822                     0.007569                  0.001420
# 0.123293                     0.007564                  0.001419
# 0.130765                     0.007559                  0.001418
# 0.138236                     0.007555                  0.001417
# 0.145708                     0.007550                  0.001416
#
#              BetaMOL 1064 (m^-1 sr^-1)
# Height(km):
# 0.115822                      0.000086
# 0.123293                      0.000086
# 0.130765                      0.000086
# 0.138236                      0.000086
# 0.145708                      0.000086
#
# [5 rows x 68 columns]

# %%
lidar_df.columns
# Out:
# Index([u'Beta355 (Mm^-1 sr^-1):', u'error beta355 (Mm^-1 sr^-1)',
#        u'Beta532 (Mm^-1 sr^-1):', u'error beta532 (Mm^-1 sr^-1)',
#        u'Beta1064 (Mm^-1 sr^-1):', u'error beta1064 (Mm^-1 sr^-1)',
#        u'alpha355 (Mm^-1 sr^-1):', u'error alpha355 (Mm^-1)',
#        u'alpha532 (Mm^-1 sr^-1):', u'error alpha532 (Mm^-1)', u'S355 (sr^-1)',
#        u'errorS355', u'S532 (sr^-1)', u'error S532', u'Angstrom ext',
#        u'error Angstrom ext', u'Angstrom b355/532', u'error Angstrom b355/532',
#        u'Angstrom b532/1064', u'error Angstrom b532/1064 ', u'voldepol h�he',
#        u'vol.depol 532', u'error vol.depol ', u'partdepolh�he',
#        u'part. depol 532', u'error part. depol', u'sounding height (km)',
#        u'Temperature (K)', u'Pressure (Pa)', u'voltdepol height',
#        u'vol. depol 355', u'error', u'partdepol height', u'part. depol 355',
#        u'error.1', u'Mixing ratio height (km)',
#        u'Water vapour mixing ratio (g/kg)', u'Height NF (km):',
#        u'Beta532 NF (Mm^-1 sr^-1):', u'error beta532 NF (Mm^-1 sr^-1)',
#        u'alpha 532 NF (Mm^-1 sr^-1):', u'error alpha532 NF (Mm^-1)',
#        u'Spar 532 NF (sr):', u'error Spar532 NF (sr)', u'Height HSRL (km):',
#        u'BetaHSRL (Mm^-1 sr^-1):', u'error betaHSRL (Mm^-1 sr^-1)',
#        u'alpha HSRL (Mm^-1 sr^-1):', u'error alphaHSRL (Mm^-1)',
#        u'Spar HSRL (sr)', u'error Spar HSRL (sr)', u'vol. depol 1064',
#        u'error.2', u'part. depol 1064', u'error.3', u'water_vapour_error',
#        u'Sounding height', u'water_vapor_mix_sonde', u'Height NF 355 (km):',
#        u'Beta355 NF (Mm^-1 sr^-1):', u'error beta355 NF (Mm^-1 sr^-1)',
#        u'alpha 355 NF (Mm^-1 sr^-1):', u'error alpha355 NF (Mm^-1)',
#        u'Spar 355 NF (sr):', u'error Spar 355 NF (sr)',
#        u'BetaMOL 355 (m^-1 sr^-1)', u'BetaMOL 532 (m^-1 sr^-1)',
#        u'BetaMOL 1064 (m^-1 sr^-1)'],
#       dtype='object')

# %%
lidar_df["Beta355 (Mm^-1 sr^-1):"].plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
import matplotlib
font = {'family': 'normal', "weight': 'bold', 'size': 22}
matplotlib.rc('font', **font)
plt.figure(figsize=(8, 8))
lidar_df[lidar_df["alpha532 (Mm^-1 sr^-1):"]<0] = 0
(lidar_df["alpha532 (Mm^-1 sr^-1):"]/1000).plot()
plt.ylabel("Extinction [1/km]")
plt.xlabel("Height [km]")
plt.xlim(0, 10)
# Out:
#   File "<ipython-input-18-3c622fdbb8f5>", line 2
#     font = {'family' : 'normal', 'weight' : 'bold', 'size' : 22}
#                                 ^
# SyntaxError: invalid syntax

# %%
lidar_df[lidar_df<0] = 0

# %%
plt.figure()
plt.plot(lidar_df["alpha355 (Mm^-1 sr^-1):"].values / (lidar_df["Beta355 (Mm^-1 sr^-1):"].values + 0.00001))
# Out:
# <img src="data:image/png;base64,...">
