# %% [markdown]
# # Testing the Double Sided Henyey Greenstein Phase Function

# %% [markdown]
# Testing the implementation and appearance of a DSHG Phase Function approximation

# %%
from __future__ import division
# %matplotlib inline
import cPickle
import datetime
from dateutil import parser
import itertools
import math
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (8.0, 8.0)
import numpy as np
import os
import pandas as pd
from scipy.integrate import quadrature, romberg, quad, fixed_quad
from scipy.interpolate import interp1d
from scipy.special import legendre
from tqdm import tqdm_notebook

from IPython.display import Image
from IPython.core.display import HTML

# %%
COEFFS_NUM = 300

# %%
g1 = 0.5
g2 = -0.5
alpha = 0.5

# %%
coeffs_quad = [(alpha*(2*i+1)*g1**i + (1-alpha)*(2*i+1)*g2**i) for i in range(COEFFS_NUM)]

# %%
mu_new = np.linspace(-1, 1, 1000)
phase_gauss = 0
for l, coeff in enumerate(coeffs_quad):
    phase_gauss += legendre(l)(mu_new) * coeff

# %%
plt.semilogy(coeffs_quad)

# %%
plt.semilogy(mu_new, phase_gauss, "x", label="accurate")
plt.legend()

# %%
ls ../../scripts
