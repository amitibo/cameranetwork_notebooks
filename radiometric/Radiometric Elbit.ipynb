# %%
# %matplotlib inline
import cv2
import glob
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (8, 8)
import numpy as np
import os
import pandas as pd
import scipy.io as sio

# %%
BASE_PATH1 = r'C:\Users\amitibo\Dropbox\Elbit Calibration\results\4102820374\2016_08_24_11_50_06'
BASE_PATH2 = r'C:\Users\amitibo\Dropbox\Elbit Calibration\results\4102820374\2016_08_24_11_55_51'

# %%
data1 = sio.loadmat(os.path.join(BASE_PATH1, 'exp_0001000_gain_000_boost_True.mat'))
data2 = sio.loadmat(os.path.join(BASE_PATH2, 'exp_0001000_gain_000_boost_True.mat'))

# %%
plt.figure()
plt.imshow(data1['array'])
plt.figure()
plt.imshow(data2['array'])

# %%
plt.imshow(np.dstack(raw2RGB(data2['array'])).astype(np.uint8))

# %%
from CameraNetwork.image_utils import raw2RGB

# %%
BASE_PATH3 = r'C:\Users\amitibo\Dropbox\Elbit Calibration\results\4102820374\2016_08_24_11_51_30'
arrays = []
for path in sorted(glob.glob(os.path.join(BASE_PATH3, '*.mat'))):
    arrays.append(sio.loadmat(path)['array'])

# %%
for arr in arrays:
    plt.plot(arr[600])
